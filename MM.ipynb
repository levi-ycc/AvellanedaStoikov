# %%
import numpy as np
import matplotlib.pyplot as plt
from MM import AS
plt.style.use('ggplot')
np.random.seed(123)

# %%
s0=100
T=1
sigma=2
dt=0.005
q0=0
gamma=0.1
k=1.5
A=140
sim_length=1000

mm=AS(s0=100, T=1, sigma=2, dt=0.005, q0=0, gamma=0.1, k=1.5, A=140, sim_length=1000)

# %%
mm.simulate()
# Out:
# PnL
# Mean of the inventory strategy v.s. symmetric strategy: 65.03 v.s. 68.98
# Standard deviation of the inventory strategy v.s. symmetric strategy: 6.3 v.s. 13.74
# INV
# Mean of the inventory strategy v.s. symmetric strategy: 0.04 v.s. 0.04
# Standard deviation of the inventory strategy v.s. symmetric strategy: 3.16 v.s. 8.44

# %%
mm.simulate()
# Out:
# PnL
# Mean of the inventory strategy v.s. symmetric strategy: 65.05 v.s. 68.24
# Standard deviation of the inventory strategy v.s. symmetric strategy: 6.69 v.s. 14.2
# INV
# Mean of the inventory strategy v.s. symmetric strategy: 0.04 v.s. -0.23
# Standard deviation of the inventory strategy v.s. symmetric strategy: 3.03 v.s. 8.41

# %%
mm.simulate()
# Out:
# PnL
# Mean of the inventory strategy v.s. symmetric strategy: 65.23 v.s. 68.3
# Standard deviation of the inventory strategy v.s. symmetric strategy: 6.58 v.s. 12.94
# INV
# Mean of the inventory strategy v.s. symmetric strategy: -0.03 v.s. -0.28
# Standard deviation of the inventory strategy v.s. symmetric strategy: 2.95 v.s. 8.3
